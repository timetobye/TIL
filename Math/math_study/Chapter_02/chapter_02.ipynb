# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_iris

# %matplotlib inline

# %% [markdown]
# ### 데이터와 행렬

# %%
iris = load_iris()
iris.data[0, :]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
from sklearn.datasets import load_digits

digits = load_digits()
samples = [0, 10, 20, 30, 1, 11, 11, 21, 31]
d = []

for sample in samples:
    d.append(digits.images[sample])

    
plt.figure(figsize=(8, 2))
for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.imshow(
        d[i], 
        interpolation='nearest', 
        cmap=plt.cm.bone_r
    )
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

# %%
d[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
v = []
for i in range(8):
    v.append(d[i].reshape(64, -1)) # 벡터화
    
plt.figure(figsize=(8, 3))
for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.imshow(
        v[i],
        aspect=0.4,
        interpolation='nearest',
        cmap=plt.cm.bone_r
    )
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
plt.tight_layout(w_pad=7)
plt.show()

# %%
v[0][0:10]
# Out:
# array([[ 0.],
#        [ 0.],
#        [ 5.],
#        [13.],
#        [ 9.],
#        [ 1.],
#        [ 0.],
#        [ 0.],
#        [ 0.],
#        [ 0.]])

# %%
A = np.array(
    [
        [11, 12, 13],
        [21, 22, 23]
    ]
)

A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23]])

# %%
from scipy import misc

img_rgb = misc.face()
img_rgb.shape
# Out:
# (768, 1024, 3)

# %%
plt.subplot(221)
plt.imshow(img_rgb, cmap=plt.cm.gray)
plt.axis('off')
plt.title("rgb color image")

plt.subplot(222)
plt.imshow(img_rgb[:, :, 0], cmap=plt.cm.gray)
plt.axis('off')
plt.title("rgb red channel")

plt.subplot(223)
plt.imshow(img_rgb[:, :, 1], cmap=plt.cm.gray)
plt.axis('off')
plt.title("rgb green channel")

plt.subplot(224)
plt.imshow(img_rgb[:, :, 2], cmap=plt.cm.gray)
plt.axis('off')
plt.title("rgb blue channel")

plt.show()

# %%
img_rgb[0]
# Out:
# array([[121, 112, 131],
#        [138, 129, 148],
#        [153, 144, 165],
#        ...,
#        [119, 126,  74],
#        [131, 136,  82],
#        [139, 144,  90]], dtype=uint8)

# %%
stock = np.array([100, 80, 50])
volume = np.array([3, 4, 5])

asset = np.dot(stock, volume)
print(asset)
# Out:
# 870

# %%
x = np.arange(10)
N = len(x)

np.ones(N) @ x / N
# Out:
# 4.5

# %%
x.mean()
# Out:
# 4.5

# %% [markdown]
# ### 유사도

# %%
import matplotlib.gridspec as gridspec

digits = load_digits()

d1, d2, d3, d4 = digits.images[0], digits.images[10], digits.images[1], digits.images[11]
v1, v2, v3, v4 = d1.reshape(64, 1), d2.reshape(64, 1), d3.reshape(64, 1), d4.reshape(64, 1)


plt.figure(figsize=(9, 9))
gs = gridspec.GridSpec(1, 8, height_ratios=[1], 
                       width_ratios=[9, 1, 9, 1, 9, 1, 9, 1])


for i in range(4):
    plt.subplot(gs[2 * i])
    
    plt.imshow(
        eval('d' + str(i+1)),
        aspect=1,
        interpolation='nearest',
        cmap=plt.cm.bone_r
    )
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(gs[2 * i + 1])
    
    plt.imshow(
        eval('v' + str(i+1)),
        aspect=0.25,
        interpolation='nearest',
        cmap=plt.cm.bone_r
    )
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
plt.tight_layout()
plt.show()

# %%
(v1.T @ v2)
# Out:
# array([[3064.]])
